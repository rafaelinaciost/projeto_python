# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelinaciost/projeto_python/blob/main/estruturas_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#importando a biblioteca pandas

# %%
#leitura dos arquivos
df1 = pd.read_excel("produtos_loja.xlsx")

# %%
#exibindo as 5 primeiras linhas
df.head
# Out:
#     PRODUTO  Unnamed: 1  QUANTIDADE  Unnamed: 3  Unnamed: 4  PREÇO
# 0       NaN         NaN         NaN         NaN         NaN    NaN
# 1      água         NaN        50.0         NaN         NaN    5.0
# 2     refri         NaN        20.0         NaN         NaN   10.0
# 3      suco         NaN        20.0         NaN         NaN    5.0
# 4  biscoito         NaN        30.0         NaN         NaN    3.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['QUANTIDADE'].plot(kind='hist', bins=20, title='QUANTIDADE')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['PREÇO'].plot(kind='hist', bins=20, title='PREÇO')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
# ...

# %%
# @title PRODUTO

from matplotlib import pyplot as plt
import seaborn as sns
df1.groupby('PRODUTO').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df1.sample(6)
# Out:
#      PRODUTO  Unnamed: 1  QUANTIDADE  Unnamed: 3  Unnamed: 4  PREÇO
# 0        NaN         NaN         NaN         NaN         NaN    NaN
# 5  chocolate         NaN        20.0         NaN         NaN    7.0
# 4   biscoito         NaN        30.0         NaN         NaN    3.0
# 1       água         NaN        50.0         NaN         NaN    5.0
# 2      refri         NaN        20.0         NaN         NaN   10.0
# 3       suco         NaN        20.0         NaN         NaN    5.0

# %%
#verificando os tipos de dados
df1.dtypes
# Out:
# PRODUTO        object
# Unnamed: 1    float64
# QUANTIDADE    float64
# Unnamed: 3    float64
# Unnamed: 4    float64
# PREÇO         float64
# dtype: object
